# %% [markdown]
# # Homework NN – <Title> — SOLUTIONS
#
# **Course:** Introduction to Neuromorphic Control
# **Term:** Summer 2026, Osnabrück University
#
# > ⚠️ **This notebook contains the reference solutions. Do not distribute to students before the deadline.**
#
# ---

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/jleugeri/NeuromorphicControl/blob/main/homework/hwNN_<topic>/solution.ipynb)
#
# > **Tip:** Click the badge above to open this notebook directly in [Google Colab](https://colab.research.google.com/).
# > Remember to update the URL in this badge when you copy the template to a new assignment folder.

# %%
# Standard imports – add more as needed
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ---
# ## Exercise 1 – <Exercise Title> (X points)
#
# Describe the exercise here.

# %%
# --- SOLUTION ---
# Insert reference solution here

# %%
# --- Test cell ---
# assert <condition>, "<failure message>"

# %% [markdown]
# ---
# ## Exercise 2 – <Exercise Title> (X points)
#
# Describe the exercise here.

# %%
# --- SOLUTION ---
# Insert reference solution here

# %%
# --- Test cell ---
# assert <condition>, "<failure message>"

# %% [markdown]
# ---
# *End of homework NN – solutions*
