# %% [markdown]
# # Homework NN – <Title>
#
# **Course:** Introduction to Neuromorphic Control
# **Term:** Summer 2026, Osnabrück University
# **Due:** YYYY-MM-DD
#
# ---
#
# ## Instructions
#
# - Complete all exercises in this notebook.
# - Write your solutions in the cells marked with `# YOUR CODE HERE`.
# - Do **not** modify the test cells.
# - Submit this notebook via the course portal before the deadline.
#
# **Name:** ________________________
# **Matriculation number:** ________________________

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/jleugeri/NeuromorphicControl/blob/main/homework/hwNN_<topic>/exercise.ipynb)
#
# > **Tip:** Click the badge above to open and run this notebook directly in [Google Colab](https://colab.research.google.com/) — no local installation required.
# > Remember to update the URL in this badge when you copy the template to a new assignment folder.

# %%
# Standard imports – add more as needed
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ---
# ## Exercise 1 – <Exercise Title> (X points)
#
# Describe the exercise here.

# %%
# YOUR CODE HERE
raise NotImplementedError("Exercise 1 not implemented yet")

# %%
# --- Test cell (do not modify) ---
# assert <condition>, "<failure message>"

# %% [markdown]
# ---
# ## Exercise 2 – <Exercise Title> (X points)
#
# Describe the exercise here.

# %%
# YOUR CODE HERE
raise NotImplementedError("Exercise 2 not implemented yet")

# %%
# --- Test cell (do not modify) ---
# assert <condition>, "<failure message>"

# %% [markdown]
# ---
# *End of homework NN*
